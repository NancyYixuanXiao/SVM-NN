# %%
import pandas as pd
wdbc_data = pd.read_csv('WDBC_raw.csv')
X_train = wdbc_data.drop('diagnosis', axis=1).drop('Unnamed: 32', axis=1)
X_train.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# 0         0.2419           ...                    25.38          17.33
# 1         0.1812           ...                    24.99          23.41
# 2         0.2069           ...                    23.57          25.53
# 3         0.2597           ...                    14.91          26.50
# 4         0.1809           ...                    22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
variance = []
from sklearn.decomposition import PCA
for k in range(3,16):
    pca = PCA(n_components=k)
    pca.fit(X_train)
    # X_train_pca = pca.transform(X_train)
    variance.append(pca.explained_variance_ratio_.mean())
plt.plot(list(range(3,16)),variance)
plt.xlabel('Number of components')
plt.ylabel('variance')
plt.show()

# %%
pca = PCA(n_components=5)
X_train_pca = pca.fit_transform(X_train)
X_train_pca
# Out:
# array([[ -2.95295294e+07,   1.17659004e+03,  -2.94913581e+02,
#           5.10075603e+01,  -8.51736879e+00],
#        [ -2.95293144e+07,   1.28574961e+03,   1.44606401e+01,
#          -3.35590736e+01,   1.78630950e+01],
#        [  5.39290716e+07,   9.65498486e+02,   3.98390159e+01,
#          -2.95941850e+00,   4.17046361e+00],
#        ...,
#        [ -2.94448774e+07,   3.31077904e+02,   4.68143809e+01,
#          -9.30775749e+00,  -9.77684292e+00],
#        [ -2.94445904e+07,   1.14143589e+03,   3.30427187e+01,
#          -1.79820164e+01,  -2.36230795e+01],
#        [ -3.02790804e+07,  -7.54562301e+02,  -8.88988219e+01,
#           2.44890742e+01,   2.52030654e+00]])
